# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
final_df = pd.read_csv("final_narratives.csv")
results_df = pd.read_csv("complete_results.csv")
print("Shape of final_narratives:", final_df.shape)
print(final_df.head())
print(final_df.columns)
#print(final_df['Category'].value_counts())
print(final_df.columns)
# Out:
# Shape of final_narratives: (5010, 12)
#                                                 name        main_category  \
# 0  Redmi 10 Power (Power Black, 8GB RAM, 128GB St...  tv, audio & cameras
# 1  OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...  tv, audio & cameras
# 2  OnePlus Bullets Z2 Bluetooth Wireless in Ear E...  tv, audio & cameras
# 3  Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...  tv, audio & cameras
# 4  OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...  tv, audio & cameras
#
#       sub_category       review_rating no_of_ratings discount_price  \
# 0  All Electronics  3.0 out of 5 stars           965        ₹10,999
# 1  All Electronics  1.0 out of 5 stars       113,956        ₹18,999
# 2  All Electronics  5.0 out of 5 stars        90,304         ₹1,999
# 3  All Electronics  1.0 out of 5 stars        24,863        ₹15,999
# 4  All Electronics  5.0 out of 5 stars       113,956        ₹18,999
#
# ...

# %%
final_df.columns = final_df.columns.str.strip()
print(final_df[['review_rating', 'cleaned_narrative']].head())
# Out:
#    review_rating                                  cleaned_narrative
# 0            3.0  "The customer mentioned that while they found ...
# 1            1.0  The customer mentioned their extremely negativ...
# 2            5.0  "The customer was thoroughly impressed with th...
# 3            1.0  The customer mentioned that the Face ID featur...
# 4            5.0  The customer mentioned that they were previous...

# %%
target = "review_rating"
X = final_df['cleaned_narrative']  
y = final_df[target] 
vectorizer = CountVectorizer()
X_vect = vectorizer.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_vect, y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error (MSE): 1.3225567420302204
# R2 Score: -0.12291945811865479
